# %% [markdown]
# # Analysing Mobile App Data
#
# In this project we will analyse data to help our developers understand what type of apps are likely to attract more users.
#
# Since the company only develop apps which are free to download and install, the main source of income is revenue of in-app ads, which means higher engagement with the ads equals higher revenue.

# %% [markdown]
# # Opening and Exploring the Data
#
# First we will define a function which we can reuse to explore the data. The function will print the defined rows and columns for the provided dataset. If the last parameter is passed it will also print the number of rows, columns and data points.

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))
        print('Number of data points:', len(dataset) * len(dataset[0]))

# %% [markdown]
# Let's get an idea of what our data looks like and it's size.
#
# - Apple store data has less number of rows but more columns than the google play data.
# - Google play data has almost 26k more data points. This is assuming all data points have a value.

# %%
from csv import reader

# open apple store data
opened_file = open('AppleStore.csv')
read_file = reader(opened_file)
apple_store_data = list(read_file)
opened_file.close()


# open google play data
opened_file = open('googleplaystore.csv')
read_file = reader(opened_file)
google_play_data = list(read_file)
opened_file.close()

# explore both data sets
print("Apple Data")
explore_data(apple_store_data[1:],0,3, True)
print()
print("Google Data")
explore_data(google_play_data[1:],0,3, True)
# Out:
# Apple Data
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# Number of rows: 7197
# Number of columns: 16
# Number of data points: 115152
#
# Google Data
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# Number of rows: 10841
# Number of columns: 13
# Number of data points: 140933

# %%
# print column names for each dataset
print('Apple data headers:')
print(apple_store_data[0])
print()
print('Google data headers:')
print(google_play_data[0])
# Out:
# Apple data headers:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
# Google data headers:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %% [markdown]
# Columns of interest:
# - price / Price: to remove paid apps
# - ipadSc_urls.num: do more screenshots result in more installs?
# - prime_genre / Genres: to understand which genres are most popular
# - size_bytes / Size: To understand if there is a correlation between app size and downloads
# - cont_rating / Rating: Does higher content rating result in less or more installs?
# - rating_count_tot: which apps have higher ratings, use this against other columns
# - user_rating:

# %% [markdown]
# # Deleting Wrong Data
# The [discussions forums](https://www.kaggle.com/datasets/lava18/google-play-store-apps/discussion) suggest some missing data.
#
# It's been suggested that there is at least one row with missing data causing value to shift over by one.
#
# Let's loop through the google dataset to see if the length of any rows do not match the length of the header row. If they don't we will delete that row.

# %%
# Get number of columns in header row
header_len = len(google_play_data[0])
print(header_len)

# Iterate through data and print the index and row if row not same length as the number of cols in the header
# Delete the any rows with missing data
for index, row in enumerate(google_play_data):
    if len(row) != header_len:
        print('índex:'+str(index))
        print(row)
        print()
        print(str(index)+ ' row deleted and replaced with the below row\n')
        del google_play_data[index] # delete the record with missing data
        print(google_play_data[index]) # print the same row to check that it's gone.
# Out:
# 13
# índex:10473
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
#
# 10473 row deleted and replaced with the below row
#
# ['osmino Wi-Fi: free WiFi', 'TOOLS', '4.2', '134203', '4.1M', '10,000,000+', 'Free', '0', 'Everyone', 'Tools', 'August 7, 2018', '6.06.14', '4.4 and up']

# %% [markdown]
# # Removing Duplicate Entries: Part One

# %% [markdown]
# First let's check for duplicate entries and print some of the apps identified as having duplicates

# %%
unique_apps = []
duplicate_apps = []

for row in google_play_data[1:]:
    app_name = row[0]
    if app_name in unique_apps:
        duplicate_apps.append(app_name)
    else:
        unique_apps.append(app_name)
        
print(len(unique_apps))
print(len(duplicate_apps))
 
print("Duplicate App Examples")
print(duplicate_apps[:10])
# Out:
# 9659
# 1181
# Duplicate App Examples
# ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack']

# %% [markdown]
# There are 1181 duplicate entries.
#
# Let's confirm they are duplicates by printing rows for a couple of the duplicate apps identified. We need to identify what columns we can use to identify the most recent record, if there are any differences.

# %%
print(google_play_data[0])
for row in google_play_data[1:]:
    name = row[0]
    if name == 'Quick PDF Scanner + OCR FREE':
        print(row)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80804', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']

# %%
print(google_play_data[0])
for row in google_play_data[1:]:
    name = row[0]
    if name == 'Google Ads':
        print(row)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Google Ads', 'BUSINESS', '4.3', '29313', '20M', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', '1.12.0', '4.0.3 and up']
# ['Google Ads', 'BUSINESS', '4.3', '29313', '20M', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', '1.12.0', '4.0.3 and up']
# ['Google Ads', 'BUSINESS', '4.3', '29331', '20M', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', '1.12.0', '4.0.3 and up']

# %% [markdown]
# The only column which appears to differ is 'Reveiws'. Let's use this to remove duplicates by keeping the duplicate where the number of reviews is highest.

# %% [markdown]
# # Removing Duplicate Entries: Part Two
#
# First let's create dictionary of the max number of reviews for each app

# %%
reviews_max = {} # store the name of the app and the highest number of reviews

for row in google_play_data[1:]:
    name, n_reviews = row[0], float(row[3]) # store app name and number of reviews
    
    # Update reviews_max if this app's reviews are higher or if it doesn't exist yet
    if (name in reviews_max and reviews_max[name] < n_reviews) or name not in reviews_max:
        reviews_max[name] = n_reviews

print(len(reviews_max))
# Out:
# 9659

# %% [markdown]
# Use the above dictionary to remove rows where the app name and reviews match, leaving us with unique records

# %%
# Add row to new clean list
android_clean = []

# make a note of what apps have been added to the cleaned data so that we don't 
# add them again if the reviews of two rows for the same app are equal
already_added = []

for row in google_play_data[1:]:
    name, n_reviews = row[0], float(row[3])
    
    if n_reviews == reviews_max[name] and name not in already_added:
        android_clean.append(row)
        already_added.append(name)
        
print(len(android_clean))
print(android_clean[1:6])
# Out:
# 9659
# [['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up'], ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up'], ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up'], ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up'], ['Smoke Effect Photo Maker - Smoke Editor', 'ART_AND_DESIGN', '3.8', '178', '19M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'April 26, 2018', '1.1', '4.0.3 and up']]

# %% [markdown]
# Let's double check one of the app which had duplicate records again

# %%
print(google_play_data[0])
for row in android_clean:
    name = row[0]
    if name == 'Quick PDF Scanner + OCR FREE':
        print(row)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']

# %% [markdown]
# We can see there is now only one record for the 'Quick PDF Scanner + OCR FREE' app instead of three 🥳

# %% [markdown]
# # Removing Non-English Apps: Part One
# Our company uses English for the app we develop so we don't need to include non-english apps in our analysis. Let's try to remove non-english apps.
#
# First we write a function which checks if string has non-english characters, if it has less than 3 non english characters return true identifying it as an english app which we will keep in our dataset.
#
# We need to keep apps with some non-english alphabet characters to prevent discluding english apps which use certain symbols or emojis that fall outside of the english alphabet character window of 127.

# %%
def isEnglish(string):
    chars_not_eng = 0
    for char in string:
        char_num = ord(char)
        if char_num > 127:
            chars_not_eng += 1

    if chars_not_eng > 3:
        return False
    else:
        return True

# %% [markdown]
# Check that our function works correctly

# %%
print(isEnglish('火车票Pro for 12306')) # should be true
print(isEnglish('Docs To Go™ Free Office Suite')) # should be true
print(isEnglish('Instachat 😜')) # should be true
print(isEnglish('爱奇艺PPS -《欢乐颂2》电视剧热播')) # should be false
# Out:
# True
# True
# True
# False

# %% [markdown]
# # Removing Non-English Apps: Part Two
# Use the above function to remove non-english apps from the google play dataset

# %%
english_apple_apps = []
for row in apple_store_data:
    if isEnglish(row[1]):
        english_apple_apps.append(row)
    
print(len(english_apple_apps))
print(english_apple_apps[:5])

english_google_apps = []
for row in android_clean:
    if isEnglish(row[0]):
        english_google_apps.append(row)
    
    
print(len(english_google_apps))
print(english_google_apps[:5])
# Out:
# 6184
# [['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'], ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1'], ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1'], ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1'], ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']]
# 9614
# [['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up'], ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up'], ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up'], ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up'], ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']]

# %% [markdown]
# After removing non-english apps from both datasets we now have 6184 rows in Apple Store data and 9614 in Google Play data

# %% [markdown]
# ### Isolating the Free Apps
# Remove non-free apps and check how many records we have left

# %%
free_eng_apple_apps = [] #4
free_eng_google_apps = [] #7

for row in english_apple_apps[1:]:
    price = float(row[4])
    if price > 0:
        free_eng_apple_apps.append(row)
        
for row in english_google_apps[0:]:
    type = row[6]
    if type == 'Free':
        free_eng_google_apps.append(row)
        
print(len(free_eng_apple_apps))
print(len(free_eng_google_apps))
# Out:
# 2961
# 8863

# %% [markdown]
# ### Most Common Apps by Genre: Part One
#
# Since we want to publish the app on both the Apple and Google markets we need to find app profiles that are successful in both stores.
#
# Our validation strategy involves a few steps:
# 1. Build a minimal android version of the app and add it to one of the market places, e.g. Google Play
# 2. If the app has a good repsonse from users, develop it further taking into account any user feedback.
# 3. If the app is poriftable after six months, build an iOS version of the app and publish to the App Store

# %% [markdown]
# #### Fields to analyse
#
# Apple
# - "prime_genre": Primary Genre
# - "user_rating" : Average User Rating value (for all version)
# - "rating_count_tot": User Rating counts (for all version)
#
# Google
# - Genres
# - Rating
# - Reviews - count of reviews - does this help?
# - Installs

# %% [markdown]
# # Most Common Apps by Genre: Part Two

# %% [markdown]
# ## Define frequency and display table functions

# %%
# frequency table
def freq_table(dataset, index):
    freq_table = {}
    for row in dataset:
        val = row[index]
        if val in freq_table:
            freq_table[val] += 1
        else:
            freq_table[val] = 1
    
    perc_table = {}
    for row in freq_table:
        perc = (freq_table[row] / len(dataset)) * 100
        perc_table[row] = perc

    return perc_table

# converts frequency table ot tuple and sorts in desc order
def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %% [markdown]
# # Most Common Apps by Genre: Part Three

# %% [markdown]
# ## Top genres on Apple Store

# %% [markdown]
# 1. The top 3 most common genres for free apps on Apple Store are Games, Education and Entertainment
# 2. Games are significantly more common at over 50% indicating the focus is largely on func apps.
# 3. Generally it seems games, education and entertainment apps are more common than other apps. News, Medical, Shopping and Catalogs being the least popular.
# 4. Games being the most common type of app may suggest there is a high demand for these types of apps, but more analysis could be done to confirm this.

# %%
# apple apps genre frequency table > prime_genre
display_table(free_eng_apple_apps, -5)
# Out:
# Games : 51.266464032421474
# Education : 9.861533265788584
# Entertainment : 6.5856129685916915
# Photo & Video : 6.112799729821006
# Utilities : 4.4579533941236065
# Productivity : 3.7825059101654848
# Health & Fitness : 3.3772374197906116
# Music : 2.397838568051334
# Lifestyle : 1.6210739614994936
# Weather : 1.3846673421141507
# Book : 1.3846673421141507
# Business : 1.21580547112462
# Sports : 1.1820330969267139
# Reference : 1.1820330969267139
# Navigation : 0.7429922323539345
# Travel : 0.6754474839581223
# Social Networking : 0.6754474839581223
# Food & Drink : 0.60790273556231
# Medical : 0.5065856129685917
# News : 0.4728132387706856
# Finance : 0.4390408645727794
# Shopping : 0.033772374197906116
# Catalogs : 0.033772374197906116

# %% [markdown]
# ## Top Categories on Google Play

# %% [markdown]
# Genres in the google play data seem to be a more granular detail, since we are only looking at the bigger picture we will use the Category field as it's defintiive and more telling of the bigger picture.
#
# 1. The top 3 most common apps on Google Play are Family, Games and Tools.
# 2. Games appear to be much less common on Google Play Store and overall a more balanced landscape of genres.
# 3. Education and photography are also less common on Google Play compared to Apple Store

# %%
# Category frequency table
display_table(free_eng_google_apps, 1)
# Out:
# FAMILY : 18.898792733837304
# GAME : 9.725826469592688
# TOOLS : 8.462146000225657
# BUSINESS : 4.592124562789123
# LIFESTYLE : 3.9038700214374367
# PRODUCTIVITY : 3.8925871601038025
# FINANCE : 3.7007785174320205
# MEDICAL : 3.5315355974275078
# SPORTS : 3.396141261423897
# PERSONALIZATION : 3.317161232088458
# COMMUNICATION : 3.2381812027530184
# HEALTH_AND_FITNESS : 3.0802211440821394
# PHOTOGRAPHY : 2.944826808078529
# NEWS_AND_MAGAZINES : 2.798149610741284
# SOCIAL : 2.6627552747376737
# TRAVEL_AND_LOCAL : 2.335552296062281
# SHOPPING : 2.245289405393208
# BOOKS_AND_REFERENCE : 2.1437436533904997
# DATING : 1.8616721200496444
# VIDEO_PLAYERS : 1.7939749520478394
# MAPS_AND_NAVIGATION : 1.399074805370642
# FOOD_AND_DRINK : 1.241114746699763
# EDUCATION : 1.1621347173643235
# ENTERTAINMENT : 0.9590432133589079
# LIBRARIES_AND_DEMO : 0.9364774906916393
# AUTO_AND_VEHICLES : 0.9251946293580051
# HOUSE_AND_HOME : 0.8236488773552973
# WEATHER : 0.8010831546880289
# EVENTS : 0.7108202640189552
# PARENTING : 0.6544059573507841
# ART_AND_DESIGN : 0.6431230960171499
# COMICS : 0.6205573733498815
# BEAUTY : 0.5979916506826132

# %%
display_table(free_eng_google_apps, 9) # genres
# Out:
# Tools : 8.450863138892023
# Entertainment : 6.070179397495204
# Education : 5.348076272142616
# Business : 4.592124562789123
# Productivity : 3.8925871601038025
# Lifestyle : 3.8925871601038025
# Finance : 3.7007785174320205
# Medical : 3.5315355974275078
# Sports : 3.463838429425702
# Personalization : 3.317161232088458
# Communication : 3.2381812027530184
# Action : 3.102786866749408
# Health & Fitness : 3.0802211440821394
# Photography : 2.944826808078529
# News & Magazines : 2.798149610741284
# Social : 2.6627552747376737
# Travel & Local : 2.324269434728647
# Shopping : 2.245289405393208
# Books & Reference : 2.1437436533904997
# Simulation : 2.042197901387792
# Dating : 1.8616721200496444
# Arcade : 1.8503892587160102
# Video Players & Editors : 1.771409229380571
# Casual : 1.7601263680469368
# Maps & Navigation : 1.399074805370642
# Food & Drink : 1.241114746699763
# Puzzle : 1.128286133363421
# Racing : 0.9928917973598104
# Role Playing : 0.9364774906916393
# Libraries & Demo : 0.9364774906916393
# Auto & Vehicles : 0.9251946293580051
# Strategy : 0.9026289066907368
# House & Home : 0.8236488773552973
# Weather : 0.8010831546880289
# Events : 0.7108202640189552
# Adventure : 0.6769716800180525
# Comics : 0.6092745120162473
# Beauty : 0.5979916506826132
# Art & Design : 0.5979916506826132
# Parenting : 0.4964458986799052
# Card : 0.4513144533453684
# Casino : 0.42874873067809993
# Trivia : 0.4174658693444658
# Educational;Education : 0.3949001466771973
# Board : 0.38361728534356315
# Educational : 0.37233442400992894
# Education;Education : 0.33848584000902626
# Word : 0.25950581067358686
# Casual;Pretend Play : 0.2369400880063184
# Music : 0.20309150400541578
# Racing;Action & Adventure : 0.16924292000451313
# Puzzle;Brain Games : 0.16924292000451313
# Entertainment;Music & Video : 0.16924292000451313
# Casual;Brain Games : 0.1353943360036105
# Casual;Action & Adventure : 0.1353943360036105
# Arcade;Action & Adventure : 0.1241114746699763
# Action;Action & Adventure : 0.10154575200270789
# Educational;Pretend Play : 0.09026289066907367
# Simulation;Action & Adventure : 0.07898002933543948
# Parenting;Education : 0.07898002933543948
# Entertainment;Brain Games : 0.07898002933543948
# Board;Brain Games : 0.07898002933543948
# Parenting;Music & Video : 0.06769716800180525
# Educational;Brain Games : 0.06769716800180525
# Casual;Creativity : 0.06769716800180525
# Art & Design;Creativity : 0.06769716800180525
# Education;Pretend Play : 0.05641430666817105
# Role Playing;Pretend Play : 0.045131445334536835
# Education;Creativity : 0.045131445334536835
# Role Playing;Action & Adventure : 0.033848584000902626
# Puzzle;Action & Adventure : 0.033848584000902626
# Entertainment;Creativity : 0.033848584000902626
# Entertainment;Action & Adventure : 0.033848584000902626
# Educational;Creativity : 0.033848584000902626
# Educational;Action & Adventure : 0.033848584000902626
# Education;Music & Video : 0.033848584000902626
# Education;Brain Games : 0.033848584000902626
# Education;Action & Adventure : 0.033848584000902626
# Adventure;Action & Adventure : 0.033848584000902626
# Video Players & Editors;Music & Video : 0.022565722667268417
# Sports;Action & Adventure : 0.022565722667268417
# Simulation;Pretend Play : 0.022565722667268417
# Puzzle;Creativity : 0.022565722667268417
# Music;Music & Video : 0.022565722667268417
# Entertainment;Pretend Play : 0.022565722667268417
# Casual;Education : 0.022565722667268417
# Board;Action & Adventure : 0.022565722667268417
# Video Players & Editors;Creativity : 0.011282861333634209
# Trivia;Education : 0.011282861333634209
# Travel & Local;Action & Adventure : 0.011282861333634209
# Tools;Education : 0.011282861333634209
# Strategy;Education : 0.011282861333634209
# Strategy;Creativity : 0.011282861333634209
# Strategy;Action & Adventure : 0.011282861333634209
# Simulation;Education : 0.011282861333634209
# Role Playing;Brain Games : 0.011282861333634209
# Racing;Pretend Play : 0.011282861333634209
# Puzzle;Education : 0.011282861333634209
# Parenting;Brain Games : 0.011282861333634209
# Music & Audio;Music & Video : 0.011282861333634209
# Lifestyle;Pretend Play : 0.011282861333634209
# Lifestyle;Education : 0.011282861333634209
# Health & Fitness;Education : 0.011282861333634209
# Health & Fitness;Action & Adventure : 0.011282861333634209
# Entertainment;Education : 0.011282861333634209
# Communication;Creativity : 0.011282861333634209
# Comics;Creativity : 0.011282861333634209
# Casual;Music & Video : 0.011282861333634209
# Card;Action & Adventure : 0.011282861333634209
# Books & Reference;Education : 0.011282861333634209
# Art & Design;Pretend Play : 0.011282861333634209
# Art & Design;Action & Adventure : 0.011282861333634209
# Arcade;Pretend Play : 0.011282861333634209
# Adventure;Education : 0.011282861333634209

# %% [markdown]
# # Most Popular Apps by Genre on the App Store

# %% [markdown]
# Again, Games comes up top here with the highest number of user reviews, with Entertainment in second place. This further suggests developing an app in the games or entertainment genre is recommended.

# %%
prime_genres_ft = freq_table(free_eng_apple_apps, -5)

for genre in prime_genres_ft:
    total = 0 # number of ratings
    len_genre = 0 # number of apps specific to each genre
    
    for row in free_eng_apple_apps:
        genre_app = row[-5]
        if genre_app == genre:
            total += float(row[5])
            len_genre += 1

    avg_user_rating = total / len_genre
    print(genre,':', str(avg_user_rating))
# Out:
# Games : 6695.863636363636
# Entertainment : 2131.5128205128203
# Music : 2759.1971830985917
# Photo & Video : 2531.519337016575
# Health & Fitness : 2679.85
# Business : 4043.472222222222
# Weather : 3248.4146341463415
# Utilities : 1326.6818181818182
# News : 3872.3571428571427
# Education : 640.972602739726
# Reference : 2400.3714285714286
# Productivity : 2247.9285714285716
# Navigation : 1174.590909090909
# Lifestyle : 902.7708333333334
# Book : 320.4146341463415
# Finance : 882.8461538461538
# Sports : 253.74285714285713
# Medical : 663.7333333333333
# Travel : 602.95
# Shopping : 2722.0
# Food & Drink : 579.5
# Social Networking : 393.0
# Catalogs : 1309.0

# %% [markdown]
# A closer look at what games have the most ratings shows games which are colourful and simple to pickup and play, and have some multiplayer or social elements.

# %%
for app in free_eng_apple_apps:
    if app[-5] == 'Games':
        print(app[1], ':', app[5]) # print name and number of ratings
# Out:
# Fruit Ninja Classic : 698516
# Clear Vision (17+) : 541693
# Minecraft: Pocket Edition : 522012
# Plants vs. Zombies : 426463
# Doodle Jump : 395261
# Draw Something : 360974
# Infinity Blade : 326482
# Geometry Dash : 266440
# Tiny Wings : 219418
# Traffic Rush : 213092
# Plants vs. Zombies HD : 163598
# Infinity Blade II : 153588
# The Room : 143908
# Plague Inc. : 143285
# Where's My Water? : 131656
# Call of Duty: Black Ops Zombies : 116601
# Sunday Lawn : 107727
# SCRABBLE Premium : 105776
# Flick Home Run ! : 98851
# Terraria : 98036
# Scribblenauts Remix : 86127
# Zombieville USA 2 : 79683
# Trivia Crack (No Ads) : 77370
# Solitaire by MobilityWare : 76720
# Call of Duty: Zombies : 63943
# Cut the Rope: Experiments : 63272
# Phase 10 Pro - Play Your Friends! : 59155
# The Sims 3 : 54408
# HB2 PLUS : 54073
# StickWars : 53821
# BATTLE BEARS: Zombies! : 50710
# Slayin : 45574
# Ski Safari : 45121
# Lane Splitter : 44567
# Bloons TD 5 : 42078
# Fieldrunners : 41633
# Super Stickman Golf : 41446
# Cat Physics : 40552
# SCRABBLE Premium for iPad : 39678
# Infinity Blade III : 37673
# Flick Kick Field Goal : 36946
# The Room Two : 36809
# Hotel Dash Deluxe : 36190
# Cartoon Wars : 35930
# Doodle God™ : 35759
# Touchgrind : 35735
# Gravity Guy : 35161
# Multiplayer for Minecraft PE : 35109
# Sally's Spa : 35074
# Goat Simulator : 34819
# iSlash : 33868
# Zombieville USA : 32988
# Grand Theft Auto: San Andreas : 32533
# Crash Bandicoot Nitro Kart 3D : 31456
# Lep's World Plus - super best platformer games : 30830
# Legendary Wars : 29739
# A Dark Room : 29540
# Rat On A Skateboard : 28672
# Bloons TD 5 HD : 28341
# Temple Run: Brave : 27593
# Five Nights at Freddy's : 27388
# Bike Race Pro - Top Motorcycle Racing Game : 26881
# Trenches : 26732
# Grand Theft Auto III : 26547
# MONOPOLY Game : 26482
# Eden - World Builder : 26419
# Rayman Jungle Run : 25517
# Monument Valley : 24909
# Real Steel : 24880
# Where's My Perry? : 24314
# Osmos for iPad : 24306
# The Room Three : 23878
# Crush the Castle : 23810
# Modern Combat 3: Fallen Nation : 23766
# Moto X Mayhem : 22557
# Offroad Legends : 22281
# Robot Unicorn Attack : 22150
# NBA JAM by EA SPORTS™ : 21648
# Peggle Classic : 21416
# Lifeline... : 21347
# BADLAND : 21325
# PAC-MAN Premium : 21292
# Dice With Buddies: Fun New Social Dice Game : 20355
# Blek : 20144
# Grand Theft Auto: Vice City : 20113
# Survivalcraft : 19784
# Sonic The Hedgehog : 19621
# Rat On A Scooter XL : 19296
# Fish Tycoon : 18943
# Virtual Families : 18920
# Sky Gamblers: Storm Raiders : 18822
# SpongeBob Moves In : 18758
# Threes! : 18494
# Sudoku⁺ : 18332
# Carnivores: Dinosaur Hunter Pro : 18306
# Reckless Getaway : 18259
# Five Nights at Freddy's 2 : 18107
# The Amazing Spider-Man : 17895
# World Cup Table Tennis™ : 17776
# Beat the Boss 2 (17+) : 17203
# I Dig It : 17190
# Harry Potter: Spells : 17023
# Wedding Dash Deluxe : 16567
# Deemo : 15855
# Block Fortress : 15430
# Teenage Mutant Ninja Turtles: Rooftop Run : 15398
# Catan : 15175
# Grand Theft Auto: Chinatown Wars : 15142
# STREET FIGHTER IV : 15056
# LIMBO : 15030
# Temple Run: Oz : 14912
# BATTLE BEARS -1 : 14910
# Gangstar Rio: City of Saints : 14724
# Osmos : 14605
# Age of Zombies™ : 14493
# Backbreaker 2: Vengeance : 14491
# Duet Game : 14407
# Hatchi - A retro virtual pet : 14381
# Tank Hero : 14361
# Bastion : 14247
# Fieldrunners 2 : 14214
# The Sims 3 Ambitions : 14202
# N.O.V.A. 3 - Near Orbit Vanguard Alliance : 13503
# Carnivores: Ice Age Pro : 13258
# Card Wars - Adventure Time Card Game : 13245
# Cartoon Wars 2: Heroes : 13049
# Modern Combat 4: Zero Hour : 12916
# Catapult King : 12799
# Seeds Pro For Minecraft - Server, Skins, Community : 12770
# Airport Scanner : 12701
# Cut the Rope 2 : 12376
# Doodle Army : 12354
# Game Dev Story : 12331
# Tiny Wings HD : 12181
# Bike Baron : 12162
# Optical Inquisitor 17+ : 12099
# Backflip Madness : 11687
# Word Chums : 11536
# :) Sudoku + : 11447
# Kingdom Rush Frontiers HD : 11447
# Ice Rage : 11190
# Bridge Constructor : 11187
# Spider Solitaire by MobilityWare : 11154
# True Skate : 11065
# Fish Out Of Water! : 11000
# Carcassonne : 10846
# PewDiePie: Legend of the Brofist : 10828
# Super Hexagon : 10748
# Pudding Monsters : 10703
# Chess Pro - with coach : 10619
# Cover Orange 2: Journey : 10604
# Sprinkle: Water splashing fire fighting fun! : 10509
# Clear Vision 2 : 10477
# LEGO Harry Potter: Years 1-4 : 10463
# Catan HD : 10382
# Skip-Bo™ Pro - The Classic Family Card Game : 10239
# Attack the Light - Steven Universe Light RPG : 10132
# Flick Golf! : 9948
# The Impossible Game : 9885
# Five Nights at Freddy's 3 : 9876
# Worms 2: Armageddon : 9870
# All-in-1 Logic GameBox : 9854
# Red Ball 4 : 9818
# Dude Perfect : 9763
# Drop Flip : 9752
# The Sims 3 World Adventures : 9744
# STREET FIGHTER IV VOLT : 9741
# Parking Mania : 9657
# Heads Up! : 9567
# Snail Bob : 9453
# Sonic the Hedgehog 2 : 9405
# Mad Skills Motocross : 9341
# Muffin Knight : 9302
# Monkey Preschool Lunchbox : 9286
# Dragon Island Blue : 9119
# Call of Duty®: Strike Team : 9097
# Ridiculous Fishing - A Tale of Redemption : 9095
# Cut the Rope: Time Travel : 9003
# SimplePhysics : 8981
# The Amazing Spider-Man 2 : 8843
# Star Wars®: Knights of the Old Republic™ : 8767
# Sushi Cat : 8718
# Hitman GO : 8673
# Sonic Jump™ : 8661
# Junk Jack Retro : 8632
# Doodle Jump HD : 8580
# Granny Smith : 8568
# TETRIS® : 8480
# Hitman Sniper : 8452
# Lep's World 2 Plus - super best platformer games : 8404
# Bloons TD 4 : 8304
# Shanghai Mahjong : 8253
# IMPOSSIBLE ROAD : 8249
# MONOPOLY for iPad : 8165
# Chess Pro with Coach - Learn,Play & Online Friends : 8138
# Unblock Me : 7973
# Bloons TD : 7941
# Cytus : 7925
# Machinarium : 7919
# Ms. PAC-MAN : 7885
# Alto's Adventure : 7824
# Super Sharp : 7776
# LEGO Batman: DC Super Heroes : 7717
# The Price is Right™ Decades : 7693
# Midway Arcade : 7639
# Shades: A Simple Puzzle Game : 7598
# 10 Pin Shuffle Pro Bowling : 7315
# Need for Speed™ Most Wanted : 7315
# Flick Champions HD : 7289
# Infinite Flight - Flight Simulator : 7100
# République : 7078
# Multiplayer Terraria edition : 6981
# Earn to Die : 6977
# Junk Jack : 6891
# Battleheart : 6879
# Spider:  The Secret of Bryce Manor : 6780
# Leo's Fortune : 6776
# Deus Ex: The Fall : 6764
# Tobuscus Adventures: Wizards : 6741
# Death Worm : 6527
# Lara Croft GO : 6431
# Kingdom Rush Frontiers : 6419
# F-Sim Space Shuttle : 6403
# FreeCell : 6340
# Pocket God: Journey To Uranus : 6278
# Kingdom Rush Origins HD : 6209
# Shadowmatic : 6136
# Lumino City : 6097
# 2XL Supercross : 6093
# FINAL FANTASY : 6091
# Resident Evil 4: PLATINUM : 6046
# Plug for Minecraft PE : 5969
# World Of Navy Ships : 5956
# Call of Duty: Zombies HD : 5853
# Cake Doodle : 5803
# hocus. : 5778
# WORMS : 5758
# Sonic The Hedgehog 4™ Episode II : 5606
# RGB Express - Mini Truck Puzzle : 5575
# Breach & Clear : 5513
# Dragon Hills : 5508
# Five Nights at Freddys 4 : 5478
# Pocket Tanks Deluxe : 5452
# LEGO Harry Potter: Years 5-7 : 5435
# Civilization Revolution 2 : 5416
# ▻Sudoku + : 5397
# Superbrothers: Sword & Sworcery EP : 5362
# Hunter Island: Monsters & Dragons : 5305
# Slender Rising : 5214
# FINAL FANTASY TACTICS: THE WAR OF THE LIONS : 5180
# Radiation Island : 5148
# Pako - Car Chase Simulator : 5115
# Rayman Fiesta Run : 5078
# Need for Speed™ Hot Pursuit : 5059
# Jelly Defense : 5058
# AVP: Evolution : 4996
# Warhammer Quest : 4965
# NBA JAM by EA SPORTS™ for iPad : 4934
# MASH : 4913
# Ticket to Ride : 4866
# Surgeon Simulator : 4820
# Tap the Frog : 4802
# Sonic The Hedgehog 4™ Episode I : 4755
# The Bard's Tale : 4746
# Lep's World 3 Plus - the super best platformer games : 4678
# World of Goo : 4675
# F18 Carrier Landing : 4656
# Chameleon Run : 4580
# FINAL FANTASY IV : 4558
# Canabalt : 4540
# SHADOWGUN : 4513
# Ricky Carmichael's Motocross Matchup Pro : 4498
# R.B.I. Baseball 14 : 4459
# Vector for iPhone : 4432
# Worms3 : 4422
# Dungeon Raid : 4401
# Neuroshima Hex : 4378
# Oceanhorn ™ : 4336
# Lifeline: Whiteout : 4327
# Cut the Rope: Time Travel HD : 4294
# Rebuild : 4095
# Slingo Supreme HD : 4094
# Jet Car Stunts : 4088
# Mini Metro : 4064
# Minecraft: Skin Studio : 4006
# Exploding Kittens® - The Official Game : 3980
# DOOM Classic : 3970
# Dictator: Revolt : 3939
# Peggle Classic HD : 3912
# Kingdom Rush Origins : 3898
# Riptide GP : 3883
# Machine World : 3875
# FTL: Faster Than Light : 3832
# Joe Danger : 3748
# Progress to 100 : 3746
# Don't Starve: Pocket Edition : 3742
# Pinball Arcade Plus : 3716
# Zip—Zap : 3711
# Ski Safari: Adventure Time - Stunt Skiing Endless Runner with Finn and BMO : 3699
# Dark Echo : 3542
# God of Light : 3542
# Rubik's® Cube : 3531
# EPOCH.2 : 3525
# Assassin's Creed Identity : 3517
# Space Marshals : 3515
# Star Command : 3473
# TETRIS® for iPad : 3464
# Drift Mania Championship : 3432
# Organ Trail: Director's Cut : 3389
# Battleheart Legacy : 3376
# Riptide GP2 : 3311
# Blocky Roads : 3282
# Cut the Rope: Magic : 3229
# Slingshot Racing : 3189
# Touchgrind BMX : 3170
# Minigore 2: Zombies : 3164
# Battle Supremacy : 3124
# MEGA MAN X : 3099
# Neo Monsters : 3093
# Mutant Fridge Mayhem - Gumball : 3090
# Earn to Die 2 : 3072
# Infectonator : 3069
# Crash Bandicoot Nitro Kart 2 : 3064
# Goat Simulator GoatZ : 3035
# Star Wars™ Pinball 5 : 3025
# Reigns : 3017
# FINAL FANTASY VI : 2998
# Sprinkle Islands : 2972
# Warhammer 40,000: Deathwatch - Tyranid Invasion : 2917
# INKS. : 2869
# XCOM®: Enemy Within : 2855
# Where's My Mickey? : 2846
# Love You To Bits : 2833
# Colossatron: Massive World Threat : 2817
# Touchgrind Skate 2 : 2816
# METAL SLUG 3 : 2798
# Stray Dog Simulator : 2781
# SimplePlanes : 2767
# The World Ends with You: Solo Remix : 2760
# FINAL FANTASY II : 2754
# Ultimate Wolf Simulator : 2737
# Lili™ : 2701
# Farming Simulator 16 : 2637
# Infect Them All 2 : Zombies : 2630
# My Virtual Girlfriend - Deluxe Dating Sim : 2609
# AirCoaster - Roller Coaster Builder : 2602
# First Words Animals : 2576
# The Trace: Murder Mystery Game - Analyze evidence and solve the criminal case : 2570
# Tozzle - Toddler's favorite puzzle : 2562
# Give It Up! : 2560
# Dude Perfect HD : 2552
# Kitty Powers' Matchmaker : 2552
# Mad Skills BMX : 2547
# Papa's Freezeria HD : 2535
# This War of Mine : 2523
# Flick Champions Winter Sports : 2505
# Teeny Titans - Teen Titans Go! Figure Battles : 2503
# Bloons TD 4 HD : 2493
# Construction Simulator 2014 : 2470
# NBA 2K17 : 2408
# Motorsport Manager : 2394
# Glow Puzzle : 2374
# Icycle: On Thin Ice : 2347
# rop : 2318
# Marvel Pinball : 2298
# The Game of Life : 2298
# Goat Simulator MMO Simulator : 2277
# Domino Drop : 2272
# Trial Xtreme 2 : 2254
# Trenches II : 2232
# Trainz Driver - train driving game and realistic railroad simulator : 2228
# Max Payne Mobile : 2183
# MONSTER HUNTER FREEDOM UNITE for iOS : 2170
# Fieldrunners for iPad : 2147
# Little Inferno HD : 2145
# Flick Home Run ! HD : 2144
# Le Havre (The Harbor) : 2125
# Weaphones WW2: Firearms Simulator : 2122
# Pursuit of Light : 2114
# Bloons Super Monkey : 2113
# Waking Mars : 2101
# Block Earth : 2089
# My Om Nom : 2074
# The Incident : 2070
# Wayward Souls : 2061
# LEGO® The Lord of the Rings™ : 2054
# Sporcle : 2044
# Skater - Skate Legendary Spots, Perfect Board Feel : 2040
# DEVICE 6 : 2036
# Earn to Die HD : 2028
# Heroes and Castles 2 : 2027
# Shoot The Zombirds : 2007
# The Secret of Grisly Manor : 1993
# FINAL FANTASY TACTICS: THE WAR OF THE LIONS for iPad : 1992
# Goblin Sword : 1983
# GeoBee Challenge HD by National Geographic : 1957
# Year Walk : 1951
# Gin Rummy Pro : 1941
# Elmo Calls : 1915
# Out There: Ω Edition : 1895
# Stray Cat Simulator : 1892
# Block Fortress: War : 1889
# Elmo Loves ABCs for iPad : 1888
# A Noble Circle : 1886
# The 7 Second Challenge : 1838
# PetWorld 3D: My Animal Rescue Premium : 1815
# WWE 2K : 1810
# FINAL FANTASY V : 1808
# RollerCoaster Tycoon® Classic : 1794
# LEGO® Marvel Super Heroes: Universe in Peril : 1784
# Reiner Knizia's Tigris & Euphrates : 1777
# Topia World Builder : 1775
# D&D Lords of Waterdeep : 1772
# Redline Rush : 1766
# Octodad: Dadliest Catch : 1752
# The Survivor: Rusty Forest : 1746
# 80 Days : 1732
# Crashlands : 1721
# Goat Simulator Waste of Space : 1709
# Table Tennis Touch : 1701
# Haunt the House: Terrortown : 1698
# Royal Trouble: Hidden Adventures HD (Full) : 1690
# Downwell : 1679
# Tentacles: Enter the Dolphin : 1678
# Lifeline: Silent Night : 1656
# Implosion - Never Lose Hope : 1644
# Broken Age ™ : 1641
# Bridge Constructor Playground : 1628
# rymdkapsel : 1622
# Sid Meier's Pirates! : 1618
# Bowmasters (Ad Free) - Top Multiplayer Bowman Game : 1608
# Papa's Burgeria : 1589
# 2XL Supercross HD : 1588
# Severed : 1580
# Puzzle Quest 2 : 1575
# Space Agency : 1565
# Mimpi Dreams : 1554
# Pacific Rim : 1522
# R.B.I. Baseball 15 : 1510
# Small World 2 : 1506
# Blendamaze : 1504
# FINAL FANTASY Ⅸ : 1502
# Draw Rider Plus : 1490
# Jurassic Park: The Game 1 HD : 1483
# Weaphones: Firearms Simulator Volume 1 : 1478
# Devil's Attorney : 1474
# Card Crawl : 1461
# Grand Theft Auto: Liberty City Stories : 1460
# DOOM II RPG : 1455
# Baldur's Gate: Enhanced Edition : 1454
# Pumped BMX 2 : 1440
# SimpleRockets : 1436
# Polar Plunge ™ : 1428
# FINAL FANTASY VII : 1421
# Sunday Lawn Seasons : 1420
# The 7th Guest : 1419
# Tank Hero: Laser Wars : 1418
# Flight! : 1411
# Draw a Stickman: EPIC 2 : 1410
# I am Bread : 1394
# The Lost City : 1393
# Agent A: A puzzle in disguise : 1390
# Deus Ex GO - Puzzle Challenge : 1385
# Bean Dreams : 1382
# FINAL FANTASY III : 1378
# iRagdoll - Ragdoll Physics : 1372
# Lifeline 2 : 1364
# Desert Golfing : 1362
# Scribblenauts Unlimited : 1350
# Titan Quest : 1350
# Virtua Tennis Challenge : 1339
# Kinectimals : 1336
# RollerCoaster Tycoon® 3 : 1334
# Bully: Anniversary Edition : 1334
# Venture Kid : 1333
# To-Fu Fury : 1331
# Vector HD : 1291
# Banner Saga : 1276
# Pandemic: The Board Game : 1259
# Duck Life : 1257
# Transistor : 1250
# Tiny Guardians : 1246
# Super Arc Light : 1246
# Guild of Dungeoneering : 1232
# Guess The Person? HD : 1227
# Thomas Was Alone : 1226
# AG Drive : 1218
# Growing Pug : 1194
# Clay Hunt : 1193
# Eagle Simulator : 1170
# Pumped: BMX : 1164
# Halo: Spartan Strike : 1159
# Family Feud™ HD : 1156
# Real Pool 3D : 1156
# Minesweeper Classic : 1140
# World of Dragons: Dragon Simulator : 1138
# Can Knockdown 3 : 1135
# CUBE SNAP : 1133
# ZENFORMS: Protectors : 1127
# Geometry Wars 3: Dimensions Evolved : 1122
# Math Ninja HD : 1121
# Reiner Knizia's Ra : 1114
# Ultimate Fox Simulator : 1112
# Offroad Legends 2 : 1108
# Agricola : 1107
# First Words Deluxe : 1101
# World Conqueror 3 : 1094
# Monkey Math School Sunshine : 1092
# Castle Raid : 1087
# Ultimate Dinosaur Simulator : 1079
# twofold inc. : 1075
# Bumpy Road : 1073
# Dominos Pro : 1072
# Octagon - A Minimal Arcade Game with Maximum Challenge : 1072
# R.B.I. Baseball 16 : 1068
# Piloteer : 1059
# UFO on Tape : 1058
# Warbits : 1051
# Dirt Trackin : 1049
# Neon Drive - '80s style arcade game : 1046
# Minecraft: Papercraft Studio : 1044
# Sumotori Dreams : 1036
# aerofly FS - Flight Simulator : 1033
# Wildlife Simulator: Wolf : 1030
# Kiwanuka : 1025
# Pixel Cup Soccer 16 : 1024
# First Strike 1.3 : 1016
# Sky Gamblers Air Supremacy : 1010
# Dungeon Village : 1000
# Secret of Mana : 990
# Cooking Academy 2: World Cuisine (Full) : 988
# Farming USA : 987
# Shadow Bug : 978
# Xenowerk : 978
# Cheetah Simulator : 976
# FRAMED : 971
# Papers, Please : 970
# The Ensign : 968
# Wild Horse Simulator : 961
# Botanicula : 959
# "HOOK" : 959
# Ultimate Horse Simulator : 958
# Batman - The Telltale Series : 953
# Nightgate : 947
# Sniper Shooter Pro by Fun Games For Free : 945
# Dungelot: Shattered Lands : 940
# Forbidden Island : 923
# Halo: Spartan Assault : 920
# Ski Safari 2 : 919
# Noodles! : 917
# The Greedy Cave : 914
# Galaxy Trucker : 901
# BADLAND 2 : 898
# Draw a Stickman: EPIC HD : 895
# Papa's Freezeria To Go! : 885
# Dust: An Elysian Tail : 884
# King of Dragon Pass : 882
# Real Fishing 3D : 880
# Phrase Party! : 878
# Able Black : 876
# Truck Simulator PRO 2016 : 875
# Hundreds : 873
# Aerofly FS 2 Flight Simulator : 863
# Snake Simulator : 859
# FINAL FANTASY III for iPad : 857
# Castle of Illusion Starring Mickey Mouse : 852
# Stone Age: The Board Game : 850
# Patrick Kane's MVP Hockey : 849
# Adventure Time Game Wizard - Draw Your Own Adventure Time Games : 848
# Jurassic Life: Tyrannosaurus Rex Dinosaur Simulator : 842
# Perchang : 839
# Snow Leopard Simulator : 837
# Jumping Horses Champions : 835
# Rules! : 835
# AJ Jump: Animal Jam Kangaroos! : 834
# Infect Them All : Vampires : 826
# Scotland Yard : 824
# har•mo•ny 3 : 823
# Mutant Mudds : 819
# Trick Shot : 816
# Ultimate Dragon Simulator : 806
# Pacific Fleet : 806
# Last Voyage : 805
# Heroes® of Might & Magic® III – HD Edition : 800
# Plug Pocketmine for Minecraft PE : 770
# Maps Pro For Minecraft PE : 768
# Ultimate Lion Simulator : 763
# LEGO® Batman: Beyond Gotham : 756
# Jumpy Horse Show Jumping : 746
# Stratego® Single Player : 739
# QWOP for iOS : 735
# Block Story Premium : 734
# Wheel of Fortune PUZZLE POP : 732
# Icebreaker: A Viking Voyage : 726
# Doom and Destiny : 725
# Death Run : Mini Game With Worldwide Multiplayer : 721
# The Walking Dead: A New Frontier : 721
# Prune : 719
# Mystery Case Files: 13th Skull HD - A Hidden Object Adventure (Full) : 718
# Til Morning's Light : 715
# The Mesh : 714
# Oddworld: Stranger's Wrath : 713
# realMyst : 708
# Tengami : 703
# Furdemption - A Quest For Wings : 703
# Tomb Raider I : 702
# Lost Echo : 684
# THE KING OF FIGHTERS '97 : 681
# Forgotten Memories: Alternate Realities : 669
# Sorcery! : 662
# Dungeons & Such Treasures,Collectibles and Dragons : 653
# _PRISM : 648
# Extreme Landings Pro : 647
# Beat Stomper : 646
# CHAOS RINGS Ⅲ : 627
# Double Dog - Dare for money if you have the nerve : 627
# Tikal : 626
# Roofbot: Puzzler On The Roof : 625
# Pocket Academy : 616
# Machines at War 3 RTS : 608
# LEGO® Jurassic World™ : 602
# Race The Sun : 602
# Bloons Supermonkey 2 : 599
# Rabbids Big Bang : 598
# Hero Emblems : 597
# "klocki" : 587
# Bio Inc. Platinum - Biomedical Plague : 573
# Autumn Dynasty Warlords : 572
# Papa's Burgeria To Go! : 570
# Eyes - the horror game : 567
# Lines the Game : 563
# Farming PRO 2015 : 560
# Pull My Tongue : 559
# Word² : 556
# Hot Springs Story : 554
# HoPiKo : 553
# Hyperburner : 545
# DEATHSMILES : 540
# METAL SLUG 1 : 540
# Tsuro - The Game of the Path : 539
# SmartGo Player : 533
# IQ Test - Pro Edition : 529
# Space Marshals 2 : 524
# PAC-MAN Championship Edition DX : 517
# Transport Tycoon : 516
# Door Kickers : 515
# The Survival Games 2 : Mini Game With Worldwide Multiplayer : 514
# Around The World in 80 Days - Hidden Object Games : 513
# Talisman : 511
# Lost Within : 510
# Beat the Boss 3 (17+) : 507
# Sentinels of the Multiverse : 505
# Colin McRae Rally : 504
# Fox Simulator : 503
# Shadow Blade : 503
# Virtual Villagers 4: The Tree of Life : 500
# Human Resource Machine : 497
# Don't Starve: Shipwrecked : 495
# The LEGO® Movie Video Game : 484
# Falcon Simulator : 482
# Weaphones: Firearms Simulator Volume 2 : 481
# SpongeBob: Sponge on the Run : 481
# Punch Club : 480
# Jurassic GO - Dinosaur Snap Adventures : 477
# Panther Simulator : 476
# Cooking Academy (Full) : 475
# Stay In The Line Pro : 474
# Incredibox : 472
# Letter Quiz - alphabet tracing for kids : 472
# WorldCraft : 3D Build & Craft : 468
# MTN : 466
# ALONE... : 465
# Brothers: A Tale of Two Sons : 460
# Mr. Robot:1.51exfiltrati0n.ipa : 459
# Power Hover : 458
# Castle Raid 2 : 452
# Legend of Grimrock : 452
# Youtubers Life - Gaming Channel : 451
# Last Horizon : 450
# Jurassic Life: Velociraptor Dinosaur Simulator : 450
# TMNT: Brothers Unite : 449
# Pumped BMX 3 : 447
# Rummikub® : 447
# Eggggg - The Platform Puker : 446
# Splendor™ : 444
# You Must Build A Boat : 444
# Raiden Legacy : 443
# Baby Rattle with Child Lock : 441
# Neon Chrome : 439
# Detective Grimoire : 439
# The Font Game : 438
# College Lacrosse 2014 : 432
# Solitairica : 431
# Tasty Planet : 430
# Train Driver Journey 4 - Introduction to Steam : 429
# Sometimes You Die : 428
# Double Dragon Trilogy : 427
# The Inner World : 425
# Evoland : 424
# VERSUS: The Lost Ones : 423
# Blokus™ – Attack, Block & Defend! : 423
# METAL SLUG 2 : 421
# Samorost 3 : 421
# DRAGON QUEST : 419
# Little Inferno : 418
# Griffin Simulator : 417
# Burrito Bison : 416
# Draw a Stickman: EPIC : 413
# Riptide GP: Renegade : 412
# Space Age: A Cosmic Adventure : 412
# Skullduggery! : 409
# Blackbar : 409
# Costume Quest : 408
# Never Alone: Ki Edition : 408
# Papa's Wingeria HD : 407
# Snowball Fight : Mini Game With Worldwide Multiplayer : 404
# THE KING OF FIGHTERS '98 : 401
# LEGO® Friends : 400
# Blackthorn Castle : 399
# Orca Simulator : 397
# Fingle : 397
# The Guides : 397
# League of Stickmen VIP Edition : 391
# Safari Simulator: Lion : 391
# Dolphin Simulator : 388
# Sword Of Xolan : 381
# Worms™ 4 : 380
# Evil Minds: Dirty Charades! : 380
# Please, Don't Touch Anything : 379
# Battlevoid: Harbinger : 374
# Baldur's Gate II:EE : 373
# ROME: Total War : 373
# Dr. Panda's Restaurant : 370
# Wildlife Simulator: Shark : 369
# Athletics: Summer Sports (Full Version) : 365
# Swapperoo : 361
# Ambition: Strategy War Game : 360
# Tone Sphere : 360
# Papa's Cupcakeria HD : 359
# Abby Monkey® Basic Skills: Preschool and Kindergarten Kids Educational Early Learning Adventure Games.▫ TeachMe Counting, Colors, Alphabet, Math, Numbers, Shapes Sorting, Patterns, Puzzles, Learn to Read Letters for Toddler Children : 358
# Pocket League Story : 357
# Monty Python's The Ministry of Silly Walks : 356
# Star Knight : 354
# FOTONICA : 352
# Home - A Unique Horror Adventure : 348
# 60 Seconds! Atomic Adventure : 346
# Patchwork The Game : 346
# Her Story : 346
# Ultimate Savanna Simulator : 344
# F1 2016 : 343
# LEGO® Ninjago™: Shadow of Ronin™ : 342
# Jurassic Park: The Game 2 HD : 341
# Devious Dungeon 2 : 335
# Wildlife Simulator: Crocodile : 333
# Athletics 2: Summer Sports : 333
# Tomb Raider II : 330
# Hyena Simulator : 327
# Sabertooth Tiger Simulator : 323
# Moorhuhn Deluxe - Crazy Chicken : 319
# Alice Trapped in Wonderland : 317
# Virtual Villagers 5: New Believers : 309
# Sputnik Eyes : 309
# Battle Supremacy: Evolution : 308
# Ski Jumping Pro : 308
# Sorcery! 2 : 308
# voi : 308
# The Walking Dead: Michonne - A Telltale Miniseries : 303
# Beat da Beat : 301
# Sneaky Sneaky : 300
# Reckless Racing 3 : 299
# Burger Shop : 299
# Feed Me Oil 2 : 296
# Tiny Rogue : 296
# DiveChamp : 295
# Polar Bear Simulator : 293
# Survivalcraft 2 : 292
# Road Not Taken : 291
# Mancala Pro : 289
# Blyss : 288
# Rule with an Iron Fish: A Pirate Fishing RPG : 286
# LVL : 284
# MLB Manager 2016 : 284
# Leap of Fate : 280
# A Brief History of the World : 280
# Hidden World : 279
# Baseball Highlights 2045 : 278
# Shopkins: Shoppie Dash! : 278
# SteamWorld Heist : 277
# Hard Time VIP (Prison Sim) : 276
# ZOOKEEPER　DX : 274
# Cafeteria Nipponica : 274
# Castles of Mad King Ludwig : 272
# Lucky Block Mod Survival Game PE - Pocket Edition : 272
# Atlantic Fleet : 271
# Elf Pets® Virtual Reindeer – The Elf on the Shelf® : 271
# Linia : 271
# A Good Snowman Is Hard To Build : 270
# Farming USA 2 : 269
# Dungeon Warfare : 264
# Tasty Planet: Back for Seconds : 264
# Owl Simulator : 263
# Rivals for Catan : 263
# LUMINES PUZZLE & MUSIC : 263
# Bridge Constructor Medieval : 262
# Infinite Tanks : 262
# Alter Ego : 262
# The Lost Ship : 262
# AZZL : 261
# Ember : 260
# Galaxy Trucker Pocket : 259
# The Martian: Official Game : 259
# Christmas Stories: Nutcracker Collector's Edition HD (Full) : 259
# Sweet Shop : 258
# Ultimate Shark Simulator : 256
# Caterzillar : 256
# Jurassic Park: The Game 4 HD : 256
# League of Light: Silent Mountain - A Hidden Object Mystery (Full) : 256
# Day of the Tentacle Remastered : 255
# King Tongue : 255
# [the Sequence] : 254
# Ultimate Bird Simulator : 254
# The Lost Heir: The Fall of Daria : 253
# Buddy & Me : 252
# Block Party : Mini Game With Worldwide Multiplayer : 250
# Haunted Manor 2 - The Horror behind the Mystery - FULL (Christmas Edition) : 248
# Dreampath - The Two Kingdoms HD - A Magical Hidden Object Game (Full) : 248
# Crypt of the NecroDancer Pocket Edition : 247
# Galactic Nemesis : 247
# Dirt Racing Mobile 3D : 245
# Take Off - The Flight Simulator : 244
# HARVEST MOON: Seeds Of Memories : 244
# Questerium: Sinister Trinity, Collector's Edition HD (Full) : 243
# STREET FIGHTER II COLLECTION : 242
# Oh...Sir! The Insult Simulator : 242
# DreamZ - Lucid Dreaming. Control your dreams! : 242
# EvoCreo - A Monster Capture RPG : 242
# Rebuild 3: Gangs of Deadsville : 238
# Plug & Play : 238
# Grim Fandango Remastered : 235
# Rusty Lake Hotel : 235
# Written Legends: Nightmare at Sea HD (Full) : 234
# Train Drive ATS : 233
# AirAttack 2 : 229
# THE KING OF FIGHTERS-i 2012 : 228
# Build Your Palace : 228
# The Impossible Quiz! for iPad : 227
# BlackOut: Bring the color back in the sky : 226
# Heroki : 225
# My Uncrowded : 224
# enzo! : 220
# SUBURBIA City Building Board Game : 217
# Craft The World - Pocket Edition : 213
# Electric RC Sim : 209
# Partia : 209
# Pulling USA : 208
# Super Slowmo Shooter : 208
# Lifeline: Flatline : 207
# Never Hillary Clinton : 207
# Jade Empire™: Special Edition : 206
# Wolf Craft : 206
# BUBBLE BOBBLE DOUBLE : 206
# SpongeBob's Game Frenzy : 205
# ULTRA4 Offroad Racing : 205
# Oddworld: Munch's Oddysee : 200
# Star Horizon : 200
# Broken Sword 5 - the Serpent's Curse : 199
# MUSYNX : 197
# SAMURAI SHODOWN II : 195
# Zenge : 194
# Lifeline: Halfway to Infinity : 194
# Summer Games 3D : 193
# Feed the Head : 193
# Aralon: Forge and Flame : 192
# Snowboard Party 2 : 188
# Skateboard Party 2 : 187
# Clue Solver - for Clue or Cluedo board games : 185
# PE Mods - Custom Keyboard for Minecraft Pocket Edition : 185
# Zodiac: Orcanon Odyssey : 184
# Imbroglio : 184
# Stickman Volleyball : 184
# Dark Parables: Queen of Sands - A Mystery Hidden Object Game (Full) : 184
# The Hero Project: Redemption Season : 183
# Shopkins Run! : 183
# Blocko. : 182
# Find–the–Line : 181
# Fix My Car: Garage Wars - Furious Street Mechanic! : 181
# Elephant Simulator : 181
# 2XL Snocross : 181
# Isabelle Dance Studio : 178
# Icewind Dale: Enhanced Edition : 177
# Adventure To Fate : Quest To The Future JRPG : 175
# The Secret of Raven Rock : 173
# Sorcery! 3 : 171
# SpongeBob Bubble Party : 171
# Galactic Keep : 169
# Sabres of Infinity : 169
# Formula Cartoon All-Stars – Crazy Cart Racing with Your Favorite Cartoon Network Characters : 168
# Banner Saga 2 : 168
# Sleepy Hollow: Mystery Legends HD (Full) : 168
# The Build Battle : Mini Game With Worldwide Multiplayer : 167
# Lifeline: Crisis Line : 167
# Mini Watch Games 14-in-1 : 166
# Twilight Struggle : 166
# Cartoon Network Superstar Soccer: Goal!!! – Multiplayer Sports Game Starring Your Favorite Characters : 166
# Construction Simulator PRO 2017 : 166
# DuckTales: Remastered : 165
# Tamagotchi Classic - The Original Tamagotchi Game : 165
# GAROU: MARK OF THE WOLVES : 162
# Swap Sword : 161
# The Westport Independent : 160
# Pocket Stables : 160
# Odd Bot Out : 157
# Warhammer 40,000: Regicide : 157
# Papa's Cupcakeria To Go! : 157
# Rusty Lake: Roots : 156
# Wild Kratts Creature Power : 155
# The Occupant : 155
# Spider: Rite of the Shrouded Moon : 155
# The Lost Treasure : 155
# Dog Sled Saga : 155
# The Bug Butcher : 153
# Living Legends: Bound by Wishes - A Hidden Object Mystery (Full) : 153
# Lost Frontier : 153
# Pixel Dungeon : 152
# Pewdiebot : 151
# Cut the Rope : 151
# Alphabet Aquarium School Adventure Vol 1: Teachme Letters - Animated Puzzle Games for Preschool and Kindergarten Explorers by 22learn : 150
# Dungeons of Chaos UNITY EDITION : 148
# Dreii : 148
# Adventures of Poco Eco - Lost Sounds: Experience Music and Animation Art in an Indie Game : 148
# Shin Megami Tensei (ENG) : 147
# Battlefleet Gothic: Leviathan : 147
# Dead Venture : 145
# Sushi Go! : 145
# Factory Balls : 144
# The Tiny Bang Story : 143
# Athletics: Winter Sports (Full Version) : 142
# The World II Hunting BOSS : 141
# sugar, sugar : 139
# LEGO® Star Wars™:  Microfighters : 139
# Special Air Wing - Flight Simulator : 138
# Divide By Sheep : 138
# Hatoful Boyfriend : 137
# Prison Life RPG : 135
# Tasty Planet: Back for Seconds HD : 135
# Rush Rally 2 : 135
# Mystery Case Files: Key To Ravenhearst - A Mystery Hidden Object Game (Full) : 134
# Adventures of Mana : 134
# Farming PRO 2016 : 133
# That Dragon, Cancer : 132
# Game Studio Tycoon – Become A Game Developer! : 131
# Five Card Quest - Tactical RPG Battles : 129
# Shopkins Magazine - once you shop…you can’t stop! : 129
# Tormentum - a Point & Click Adventure : 127
# Dark Parables: Goldilocks and Fallen Star (Full) : 127
# Mystery of the Ancients: Mud Water Creek (Full) : 127
# Jazza's Arty Games : 127
# BO3 Ultimate Utility™ for Call of Duty Black Ops 3 : 127
# Tomb Journey (Ancient ruins fantasy adventure) : 126
# Flipped Out – The Powerpuff Girls Match 3 Puzzle / Fighting Action Game : 124
# SPL-T : 124
# Maze: Subject 360 HD - A Mystery Hidden Object Game (Full) : 123
# Wildlife Simulator: Bear : 122
# BLUK : 119
# The Enchanted Books : 119
# Colorcube : 119
# Metro 2033: Wars : 118
# Ys Chronicles 1 : 118
# BuriedTown - World's First Doomsday Survival Themed Game : 118
# Pocket Aquarium: Craziest Aquarium : 118
# Papa's Pizzeria To Go! : 118
# Doom & Destiny Advanced : 117
# Return to Grisly Manor : 116
# Campaign Manager - A Presidential Election Simulation Game : 116
# Weaphones Antiques: Firearms Simulator : 116
# Wars of the Roses - Rosenkönig : 115
# Flight Unlimited 2K16 - Flight Simulator : 115
# Hot Trigger : 115
# Dark Romance: The Swan Sonata HD - A Mystery Hidden Object Game (Full) : 115
# Subliminal Realms: The Masterpiece HD - A Hidden Object Mystery (Full) : 115
# AirTycoon 4 : 114
# Snail Bob 2 Deluxe : 114
# Teenage Mutant Ninja Turtles: Portal Power : 113
# TruckSimulation 16 : 113
# One Button Travel : 111
# The Lost Heir 2: Forging a Kingdom : 111
# Tales From Deep Space : 110
# Game Studio Tycoon 2: Next Gen Developer : 110
# Redemption Cemetery: The Island of the Lost - A Mystery Hidden Object Adventure (Full) : 109
# Dark Tales: Edgar Allan Poe’s The Mystery of Marie Roget HD - A Hidden Object Mystery (Full) : 109
# Incredipede : 108
# Lightbot : Programming Puzzles : 108
# Head of State : 106
# oh my giraffe : 106
# Paul Pixel - The Awakening : 106
# Sproggiwood : 105
# Mystery Tales: Her Own Eyes HD - A Hidden Object Mystery (Full) : 104
# Eisenhorn: XENOS : 100
# NextGen Car Game Racing : 100
# Private School Days : 99
# Super Powerboy : 99
# Isoland : 99
# A Tiny Game of Pong : 99
# Vector 2 Premium : 99
# Add-Ons Studio for Minecraft : 97
# Ask Drift0r (for Call of Duty: Black Ops 3) : 97
# NEO TURF MASTERS : 96
# Bombsquad - Defuse the Bomb : 96
# Runestone Keeper : 95
# Delicious - Emily's Tea Garden : 95
# Elmo Loves 123s : 95
# Legend of the Skyfish : 95
# Apollo Justice Ace Attorney : 95
# Heads Up! Kids : 94
# Vikings: an Archer's Journey : 94
# Skat : 94
# Zyon_RhythmGame : 93
# WonderCat Adventures : 93
# The Enchanted Cave 2 : 92
# Choice of the Pirate : 92
# Gemini - A Journey of Two Stars : 91
# Mystery Trackers: Winterpoint Tragedy - A Hidden Object Adventure (Full) : 91
# Doc McStuffins: Mobile Clinic Rescue : 91
# Magic Tower Touch : 91
# Fear For Sale: The 13 Keys HD - A Scary Hidden Object Mystery (Full) : 90
# Either : 89
# Dangerous Games: Illusionist HD - A Magical Hidden Object Mystery (Full) : 89
# Midnight Calling: Anabel - A Mystery Hidden Object Game (Full) : 88
# The Agency of Anomalies: Mind Invasion HD - A Hidden Object Adventure (Full) : 88
# Submerged: Miku and the Sunken City : 88
# Fix My Car: Custom Mods : 87
# Grim Tales: The Heir - A Mystery Hidden Object Game (Full) : 87
# Out There Chronicles - Ep. 1 : 87
# Mystery Tales: Alaskan Wild HD - A Mystery Hidden Object Adventure (Full) : 86
# Stellar Wanderer : 86
# Blackwell 1: Legacy : 86
# Grim Tales: The Final Suspect - A Hidden Object Mystery (Full) : 86
# Dark Dimensions: Shadow Pirouette HD - A Scary Hidden Object Game (Full) : 86
# Invisible, Inc. : 86
# Surface: Alone in the Mist - A Hidden Object Mystery (Full) : 86
# Disc Golf Game : 85
# Myths of the World: Black Rose HD - A Hidden Object Adventure (Full) : 84
# The Secret Order: Beyond Time HD - A Hidden Object Adventure (Full) : 84
# Dokuro : 84
# A Short Tale : 83
# illi : 83
# Fear For Sale: Phantom Tide HD - A Scary Hidden Object Mystery (Full) : 83
# Haunted Hotel: The X (Full) : 83
# Sable Maze: Twelve Fears HD - A Mystery Hidden Object Game (Full) : 83
# Draw It : Mini Game With Worldwide Multiplayer : 82
# Mystery Case Files: Ravenhearst Unlocked - A Hidden Object Adventure (Full) : 82
# Surface: Return to Another World - A Hidden Object Adventure (Full) : 82
# Immortal Love: Letter From The Past Collector's Edition - A Magical Hidden Object Game (Full) : 82
# Emily Wants To Play : 81
# BCM Surfing Game - World Surf Tour : 81
# Melody Jams : 81
# Evo Explores : 81
# Beyond: Light Advent Collector's Edition (Full) : 81
# Guns of Infinity : 80
# MadOut Open City : 80
# Asva The Monkey HD : 80
# Paperback: The Game : 80
# Agatha Christie - The ABC Murders (FULL) : 80
# I Keep Having This Dream : 79
# Dark Romance: Kingdom of Death HD - A Hidden Object Adventure (Full) : 79
# Forbidden Desert : 78
# Bus Simulator PRO 2017 : 78
# Danse Macabre: Deadly Deception - A Mystery Hidden Object Game (Full) : 78
# Rugby Nations 16 : 78
# Super City: Special Edition : 78
# Dark Dimensions: Homecoming HD - A Hidden Object Mystery (Full) : 78
# PE Servers - Custom Keyboard for Minecraft Pocket Edition : 77
# Duck Life: Retro Pack : 77
# Haunted Hotel: Eternity - A Mystery Hidden Object Game (Full) : 77
# Microgue : 77
# Dark Realm: Princess of Ice HD - A Mystery Hidden Object Game (Full) : 76
# Lea Born for Adventure : 76
# Mystic Diary: Haunted Island HD (Full) : 76
# Labyrinths of the World: Changing the Past HD - A Mystery Hidden Object Game (Full) : 76
# Abzorb : 76
# Papa's Taco Mia HD : 75
# Nevertales: Legends - A Hidden Object Adventure (Full) : 75
# House of 1000 Doors: Evil Inside HD - A Hidden Object Adventure (Full) : 75
# Bridge Constructor Stunts : 75
# Dream Machine : The Game : 75
# Samurai of Hyuga Book 2 : 74
# 8-Bit RPG Creator : 73
# Quell Zen+ : 73
# Train Drive ATS 2 : 73
# Mystery Trackers: Nightsville Horror HD - A Hidden Object Adventure (Full) : 72
# Hunting USA : 72
# Royal Detective: Legend of The Golem - A Hidden Object Adventure (Full) : 72
# Small Town Terrors: Galdor's Bluff HD - A Magical Hidden Object Mystery (Full) : 71
# The Curio Society: Eclipse over Mesina HD - A Hidden Object Mystery (Full) : 71
# Phantasmat: The Dread of Oakville - A Mystery Hidden Object Game (Full) : 71
# Chimeras: The Signs of Prophecy - A Hidden Object Adventure (Full) : 71
# Space War HD : 71
# Cut the Rope HD : 71
# Teenage Mutant Ninja Turtles: Battle Match Game : 70
# Grim Tales: Threads of Destiny - A Hidden Object Mystery (Full) : 70
# Vectradius : 70
# Witches' Legacy: Slumbering Darkness HD - A Hidden Object Mystery (Full) : 69
# Kill the Plumber World : 69
# iFleeing : 69
# Crazy Craft Mod Guide for Minecraft Pc :Complete and Ultimate for Players : 69
# Grim Facade: Hidden Sins - A Hidden Object Mystery (Full) : 69
# Power Ping Pong : 69
# Haunted Legends: The Secret of Life - A Mystery Hidden Object Game (Full) : 69
# Fear for Sale: The House on Black River (Full) : 69
# Wars Of Warlords : Mini Game With Worldwide Multiplayer : 69
# Hero Siege: Pocket Edition : 68
# Retro City Rampage DX : 68
# Thirty Days & Seven Seas – Pirate Battle Board Game Starring Clarence, Jeff and Sumo : 68
# European Mystery: Flowers of Death HD (Full) : 68
# Carbon Warfare : 68
# Myths of the World: The Heart of Desolation - A Hidden Object Adventure (Full) : 68
# Hero Generations : 67
# Block Sky War (Luck of the Draw) : Mini Game With Worldwide Multiplayer : 67
# Watch Games : 67
# Mystery Trackers: Paxton Creek Avengers - A Mystery Hidden Object Game (Full) : 67
# Dictator 2: Evolution : 67
# BMO Snaps - Adventure Time Photo Game : 67
# Amaranthine Voyage: The Obsidian Book - A Hidden Object Adventure (Full) : 67
# Bus Simulator PRO 2016 : 67
# PuppetShow: The Face of Humanity (Full) : 66
# Train Kit : 66
# Beyondium : 66
# End Space VR for Cardboard : 66
# Shadow Wolf Mysteries: Tracks of Terror - A Hidden Object Adventure (Full) : 66
# Fear for Sale: Endless Voyage HD - A Mystery Hidden Object Game (Full) : 66
# Dead Reckoning: Brassfield Manor - A Mystery Hidden Object Game  (Full) : 66
# Nanuleu : 65
# Game Cheats - Super-Mario Universe 2 Luigi Galaxy Starship Edition : 65
# TNNS : 65
# Anime Studio Story : 65
# Haunted Legends: The Dark Wishes - A Hidden Object Mystery (Full) : 65
# Hidden Expedition: The Fountain of Youth (Full) : 65
# Myths of the World: The Whispering Marsh - A Mystery Hidden Object Game (Full) : 65
# Pixel Cup Soccer : 64
# The Secret Elevator : 64
# OPERATION DRACULA : 64
# The Secret Order: The Buried Kingdom HD (Full) : 63
# Matt Duchene's Hockey Classic : 63
# Furniture Mod PE : 63
# VERSUS: The Elite Trials : 62
# Phantasmat: Behind the Mask (Full) : 62
# Albert & Otto : 62
# Cadenza: Havana Nights (Full) : 61
# Cliff Diving Champ : 61
# Raildale - Railroad & Railway Building Game : 61
# YANKAI'S TRIANGLE : 61
# Football Manager Touch 2017 : 61
# Dark Tales: Edgar Allan Poe’s The Tell-tale Heart - A Hidden Object Mystery (Full) : 61
# Fix My Truck: 4x4 Offroad Truck Mechanic Simulator : 61
# RunGunJumpGun : 60
# Shadow Blade: Reload : 60
# Level: A Simple Puzzle Game : 60
# Sorcery! 4 : 60
# The Forgotten Room : 59
# Party Hard Go : 59
# Kahuna : 59
# Dead Reckoning: The Crescent Case - A Mystery Hidden Object Game (Full) : 58
# Space Grunts : 58
# Hidden Expedition: Dawn of Prosperity - A Mystery Hidden Object Game (Full) : 58
# The Curio Society: New Order HD (Full) - Adventure : 58
# Game Studio Tycoon 3 – Gaming Business Simulation : 58
# Syberia 2 (FULL) : 58
# ROMANCING SAGA 2 : 58
# Off the Record: Liberty Stone - A Mystery Hidden Object Game (Full) : 57
# Danse Macabre: Lethal Letters - A Mystery Hidden Object Game (Full) : 57
# Whispering Willows : 57
# Fran Bow Chapter 1 : 57
# Final Cut: Fame Fatale - A Hidden Object Adventure (Full) : 57
# Sudoku Pro Edition : 56
# Secrets of the Dark: Eclipse Mountain Collector's Edition HD (Full) : 56
# Fireboy & Watergirl 2 - The Forest Temple : 56
# bloxorz : 56
# Circa Infinity : 56
# Rescue the Enchanter : 55
# Secrets of the Dark: Mystery of the Ancestral Estate HD - A Mystery Hidden Object Game (Full) : 55
# Lanota : 55
# Football Manager Mobile 2017 : 55
# BMX Streets : 54
# Labyrinths of the World: Forbidden Muse HD - A Mystery Hidden Object Game (Full) : 54
# Eklips : 54
# Survival: Wicked Forest : 53
# Moto x3m : 53
# Redemption Cemetery: Clock of Fate - A Mystery Hidden Object Game (Full) : 53
# Heroes of Normandie : 53
# Treasure Buster : 53
# Santa Spy Cam! I Caught Santa! : 52
# Witches' Legacy: The Dark Throne HD (Full) : 52
# Minesweeper - Widget Edition : 52
# Haunted Hotel: Phoenix - A Mystery Hidden Object Game (Full) : 52
# Danse Macabre: Thin Ice - A Mystery Hidden Object Game (Full) : 52
# Heroes of Loot 2 : 51
# Drakomon GO - 3D Monster Battle Game : 50
# Train Driver Journey 8 - Winter in the Alps : 50
# Vampire Legends: Untold Story of Elizabeth (Full) : 50
# Final Cut: Fade To Black - A Mystery Hidden Object Game (Full) : 49
# Primordia : 49
# Bubble Mags : 49
# Bulb Boy : 49
# Rubek : 48
# Amaranthine Voyage: The Orb of Purity (Full) : 48
# Burly Men at Sea : 48
# Ice Fishing Derby Premium : 47
# Telepaint : 47
# Whispered Secrets: Into the Beyond - A Hidden Object Adventure (Full) : 47
# Atomic Super Lander : 47
# Fear for Sale: City of the Past HD - A Hidden Object Mystery (Full) : 46
# Blackwell 5: Epiphany : 46
# Go Rally : 46
# OffRoad Drive Desert : 46
# Mia and me - Free the Unicorns! : 45
# Sea of Lies: Tide of Treachery - A Hidden Object Mystery (Full) : 45
# Note Rush: Learn Music Sight Reading + Piano Notes : 45
# Sleep Attack TD : 45
# Punished Talents: Stolen Awards HD - A Mystery Hidden Object Game (Full) : 45
# Siralim 2 (RPG / Roguelike) : 44
# Concrete Jungle : 44
# Forged in Battle: Man at Arms : 44
# Spirits of Mystery: Chains of Promise - A Hidden Object Adventure (Full) : 44
# Alice in Wonderland Puzzle Golf Adventures : 43
# Ominous Objects: Phantom Reflection HD - A Hidden Object Adventure (Full) : 43
# Echoes of the Past: Wolf Healer HD (Full) : 43
# Egz – The Origin of the Universe : 43
# ISLANDS: Non-Places : 43
# Bob's Burgers Pinball : 43
# TankTrouble - Mobile Mayhem : 42
# DMBX 2 - Mountain Bike and BMX : 42
# Astrå : 42
# Pocket Arcade Story : 41
# The Game - Play ... as long as you can! : 41
# Phantasmat: The Endless Night HD - A Mystery Hidden Object Game (Full) : 41
# Get 'Em : 40
# CATTCH : 40
# Carp Fishing Simulator : 39
# Blitz Breaker : 39
# French Belote : 39
# FATAL FURY SPECIAL : 39
# Odysseus: Long Way Home HD (Full) : 39
# Demon's Rise 2: Lords of Chaos : 39
# Shadow Wolf Mysteries: Curse of Wolfhill (Full) : 39
# Loop & Dot : 39
# Parallyzed: Surreal Platform Runner : 38
# Fireman Sam - Fire & Rescue : 38
# The Swords : 38
# Sable Maze: Soul Catcher HD - A Mystery Hidden Object Game (Full) : 38
# Pug's Quest : 38
# Football Chairman Pro : 37
# minimize : 37
# SKYHILL : 37
# Colt Express : 36
# Paper Monsters Recut : 36
# Dig Deep! : 36
# Tank Battle: 1945 : 36
# Cloud Chasers - A Journey of Hope : 36
# Saga of the North Wind : 36
# Skateboard Party 3 ft. Greg Lutzka : 36
# NO THING - Surreal Arcade Trip : 35
# Off the Record: The Final Interview (Full) : 35
# Replica : A Little Temporary Safety : 35
# Station Manager : 35
# Agricola All Creatures Big and Small : 35
# Talisman: Horus Heresy : 34
# Ominous Objects: Trail of Time HD (Full) : 34
# Ys Chronicles II : 34
# Dark Dimensions: City of Ash HD - A Mystery Hidden Object Game (Full) : 33
# French Tarot : 33
# Moorish Kingdom : 33
# Pointless Quiz : 32
# Secrets of the Dark: The Flower of Shadow (Full) : 32
# Proton Pulse for Google Cardboard : 32
# Aurora - Puzzle Adventure : 31
# Mr Jack Pocket : 31
# Glass Road : 31
# My Town : Beauty Contest : 31
# Blackwell 4: Deception : 31
# Smashing The Battle : 30
# kubic : 30
# Crap! I'm Broke: Out of Pocket : 30
# Slip Away Mystify : 29
# Dead Shell: Roguelike RPG : 29
# Empyrean : 29
# Soccer 17 : 29
# Vulture Island : 29
# Tour de France 2016 - the official game : 28
# Smart Baby Shapes: Learning games for toddler kids : 28
# Ninja Boy Adventures - Bomberman edition : 28
# Journey Below : 28
# Superkick Party : 27
# Future War：Reborn- Zombie Survival Tatics TPS : 27
# The Lost Shield : 27
# Pang Adventures : 27
# Hollywood Game Night : 27
# Lost Journey - Nomination of Best China IndiePlay Game : 27
# The Abandoned : 26
# Fix My Car: Classic Muscle Mods Mechanic - Junkyard Blitz! : 26
# Hardcore Dirt Bike 2 : 26
# Island Delta : 26
# Shell Shock 1.5 : 26
# Lotto Out! - Mexican Loteria : 26
# X-Tactics : 25
# Roll Turtle : 25
# Beams. : 25
# 2-bit Cowboy Rides Again : 25
# Blitz Survival Games - Multiplayer Pixel Master Mini Games : 24
# Momoka: An Interplanetary Adventure : 24
# Civil War: Bloody April : 24
# Mountain Biker : 24
# Dog Mendonca : 24
# Dead In Bermuda : 24
# T-Rex Simulator : 24
# Lacrosse Arena : 23
# LOUD on Planet X : 23
# Ellipsis - Touch. Explore. Survive. : 23
# Hide it Hillary! : 23
# Last City : 23
# Rainmaker - The Beautiful Flood : 23
# Journey of 1000 Stars : 22
# Agent Gumball - Roguelike Spy Game : 22
# AngerForce - Strikers : 22
# Red Dwarf XI : The Game : 22
# Runaway Toad : 22
# Tennis Club Story : 22
# Pango Build City : 21
# Puzzle Strike : 21
# Arcadecraft : 21
# Bar Oasis 2 Aftertaste 01 : 21
# Le Havre: The Inland Port : 21
# Goosebumps Night of Scares. : 20
# Myths of the World: Black Rose - A Hidden Object Adventure (Full) : 20
# Paper Train: Traffic : 20
# Goo Saga : 20
# Drive Simulator 2016 : 19
# Final Cut: The True Escapade HD - A Hidden Object Mystery Game (Full) : 19
# The Manga Works : 19
# Puzzlepops! : 19
# Ice Princess Mermaid Salon: Girls Makeover Games : 19
# Cannonfire Concerto : 19
# Mystery of Fortune 2 : 19
# Tank Battle: Blitzkrieg : 19
# Baum : 19
# Open Sorcery : 19
# Red 7 - play Digital Red7 Card Game with Friends : 18
# Cognition Game : 18
# Scary Doll : 18
# Into Light : 18
# Witches' Legacy: Hunter and the Hunted HD - Hidden Objects, Adventure & Magic (Full) : 18
# Arthur's Adventures-Road of Glory:Pocket Edition : 18
# Riff Racer: Race Your Music : 18
# Alchemic Maze : 17
# Demon Hunter: Chronicles from Beyond (Full) : 17
# Shield Designer for Minecraft : 17
# Survival Island 2: Dinosaur Hunter : 17
# A New Life : 17
# Peppa Pig: Seasons - Autumn and Winter : 17
# Flipominos : 17
# WitchSpring2 : 17
# Small Town Terrors: Galdor's Bluff - A Magical Hidden Object Mystery (Full) : 17
# STEINS;GATE : 16
# Mud Bogger ( 3D Monster Truck Driving & Racing Games ) : 16
# Donut vs Donut : 16
# Superhero Girl Salon: Kids Makeup and Dressup Game : 16
# Fleeing the Complex : 15
# AdivínaT - Adivina las palabras : 15
# Flud. : 15
# Dark Tales: Edgar Allan Poe’s The Mystery of Marie Roget - A Hidden Object Mystery (Full) : 15
# Dinosaur Games: Puzzle for Kids : 15
# The End of the World by Sean Wenham : 15
# Recontact: Istanbul : 14
# Lucky Block Mod for Minecraft PC Edition - Pocket Guide : 14
# Cell Surgeon - A Unique 3D Match 4 Strategy Game! : 14
# Flood of Light : 14
# Knotmania : 14
# Civil War: 1865 : 14
# GeoBots VR : 13
# Snowball!! : 13
# Phantasmat: The Endless Night - A Mystery Hidden Object Game (Full) : 13
# Moto Madness - 3d Motor Bike Stunt Racing Game : 13
# Unstoppable: Highway Truck Racing Game : 13
# Mods Explorer – for PocketMine MP : 12
# Super Spy Girl Salon: Spa, Makeup and Dressup Game : 12
# Stealers Steal: A thief's quest for gold : 12
# Attack Heroes : 12
# Assault on Arnhem : 12
# Team Drift Cats : 12
# Toby: The Secret Mine : 12
# Defend Pizzeria Craft Shop : 11
# Crusader Kings: Chronicles : 11
# Bob the Builder™: Build City : 11
# Plead the Fifth - The Game : 11
# CombineRobot : 11
# Hey Duggee: The Big Badge App : 11
# Ice Queen Prom Salon: Princess Makeover Girls Game : 11
# Boulder Dash® 30th Anniversary™ Premium : 11
# Dark Dimensions: Homecoming - A Hidden Object Mystery (Full) : 10
# Tokyo Wizard : 10
# Shopkins: Top Trumps : 10
# Tube Heroes Racers : 10
# The Collider 2 : 10
# Elf Pets® Pup — The Elf on the Shelf® : 10
# unWorded : 10
# Sinless: Remastered : 10
# KING OF KARTS: Single- & Multiplayer Battles. : 9
# New Star Soccer G-Story : 9
# Tiki Taka World Soccer : 9
# Mixed Macho Arts : 9
# City Run London : 9
# Reckless Racing HD : 9
# First Year Demons : 9
# Mystery Trackers: Nightsville Horror - A Hidden Object Adventure (Full) : 9
# Unmatch : 9
# Bob Mod : 9
# Lamper VR: Firefly Rescue : 9
# Amaranthine Voyage: The Shadow of Torment HD - A Magical Hidden Object Adventure (Full) : 9
# Dr. Decks for "Clash Royale" : 9
# Magic Princess - Girls Makeup & Dressup Salon Game : 8
# Fear For Sale: Nightmare Cinema HD - A Mystery Hidden Object Game (Full) : 8
# Black Hole Joyrider : 8
# Sally's Law : 8
# PPTAN : 8
# Tractor Crew: Operation Cleanup : 8
# Smooth Operator! : 8
# Cricket Captain 2016 : 7
# Little Briar Rose : 7
# Super SteamPuff : 7
# Dumber League : 7
# The Island:Brave Heart : 7
# Don't Die, Mr. Robot! : 7
# Halloween Makeover: Spa, Makeup & Dressup Salon : 7
# VR RollerCoaster for Cardboard : 7
# Jurassic VR for Google Cardboard : 7
# Civil War: Wilson's Creek : 6
# Beach Volleyball 2016 : 6
# Figure Skater - Girls Makeup & Dressup Salon Game : 6
# Smart Baby ABC Games: Toddler Kids Learning Apps : 6
# Mystery Tales: The Twilight World HD - A Hidden Object Adventure (Full) : 6
# Soccer Sumos - Multiplayer party game! : 6
# Civil War: 1861 : 6
# Fire and Fury: English Civil War : 5
# Please, Don't Touch Anything 3D : 5
# Zasa : An AI Story : 5
# Gymnastics Girl Jump American Athlete sports PRO : 5
# Smart Baby Sorter HD - Early Learning Shapes and Colors / Matching and Educational Games for Preschool Kids : 5
# Amaranthine Voyage: The Shadow of Torment - A Magical Hidden Object Adventure (Full) : 4
# Fold+ : 4
# Huetopia : 4
# Craft The World - Episodes Edition : 4
# Сluster Traffic: Parkour Trucks Pro : 4
# Comblosion : 4
# Blade of Elemental : 3
# Patchmania KIDS - A Puzzle About Bunny Revenge! : 3
# Fire Fu : 3
# Lost Fishy Ultimate Challenge : 3
# FunBridge Quiz 3 : 3
# A Busy Day for Elmo: Sesame Street Video Calls : 3
# We’re Going on a Bear Hunt : 3
# Smart Baby Shapes FOOD: Fun Jigsaw Puzzles and Learning Games for toddlers & little kids : 3
# Fantasy Princess - Girls Makeup & Dress Up Games : 3
# The Snowman & The Snowdog Game : 3
# Apestorm: Full Bananas : 3
# RETSNOM : 2
# Flappy Marine : 2
# Spoofr — GPS & Location Simulator : 2
# Santa was in my House! Catch Santa Camera : 2
# Cars & Vehicles Puzzle Game for toddlers HD - Children's Smart Educational Transport puzzles for kids 2+ : 2
# The Orchard by HABA - colors & shapes for children : 2
# Yiannimize Racing : 2
# Mystery Tales: The Twilight World - A Hidden Object Adventure (Full) : 2
# Dikie & Dukie: Learn to Read in Spanish HD : 2
# Montessori Nature : 1
# Bullet'nTunes : 1
# Should Shoot : 1
# Fragment's Note : 1
# Clouds & Sheep 2 Premium : 1
# Kaiser 64 : 1
# Fear For Sale: Nightmare Cinema - A Mystery Hidden Object Game (Full) : 1
# GUNTAI : 1
# Ducky Fuzz : 1
# NOT ALONE - Story of a bird : 1
# Pop Jump : 1
# Forevolution : 0
# Base Invaders - For Big Narstie : 0
# GROW：JOURNEY TO THE LIGHT : 0
# Labo Halloween Car(4+) : 0
# Asymmetric : 0
# Shapes & Colors Learning Kids Games for girls 2 + : 0
# Dinos Jump - Dinosaur action game for kids : 0
# Kanazawa Shogi 2 : 0
# Fragment's Note -After Stories- : 0
# Daisy Chain : 0
# Green Game TimeSwapper : 0
# Bibi & Tina: Pferdeabenteuer : 0
# Bangers Unlimited 2 : 0
# Infinity Duels : 0
# Cannon Flight : 0
# Fragment's Note2 Side:雪月 : 0
# Fragment's Note2 Side:雫 : 0
# What's that sound? - Educational game for children : 0
# Devil Tower 2 : 0
# NZ vs Loons : 0
# Lumps of Clay : 0
# Saloons Unleashed : 0
# Mystic R : 0
# Werewolf Special Package : 0
# The Dance of the Little Water Drops : 0
# Table Speed : 0
# Clash of Crime Mad City Full : 0
# EggPunch 2 - adventure puzzle game : 0
# iFleeing! : 0
# VR MUSEUM : 0
# Mundo Lanugo en Navidad – Juegos Navideños : 0
# BrainConnect : 0
# Brain IQ Test Adventure : 0
# Be-be-bears! : 0
# Hey Duggee: We Love Animals : 0

# %%
for app in free_eng_apple_apps:
    if app[-5] == 'Business':
        print(app[1], ':', app[5]) # print name and number of ratings
# Out:
# Scanner Pro - PDF document scanner app with OCR : 31912
# Splashtop Personal - Remote Desktop : 29376
# TurboScan™ Pro - document & receipt scanner: scan multiple pages and photos to PDF : 28388
# iScanner - PDF Document Scanner App : 8675
# PDF Reader Pro Edition - Annotate,edit & sign PDFs : 7033
# InstaLogo Logo Creator - Graphic design maker : 6263
# Tiny Scanner+ - PDF scanner to scan document, receipt & fax : 5611
# HotSchedules : 3292
# ScanBizCards Business Card Reader : 3166
# TapeACall Pro - Call Recorder For Phone Calls : 2951
# CamCard - Business card scanner & reader : 2923
# File Manager Pro App : 2154
# Scanner For Me - PDF Scan with OCR for Documents : 1976
# AudioNote - Notepad and Voice Recorder : 1756
# SuperCam_Pro : 1399
# PDF Converter - Convert Documents, Photos to PDF : 1294
# Voice Translate Pro : 1158
# Fax from iPhone - send fax app : 1039
# Genius Scan+ - PDF Scanner : 916
# OfficeSuite Pro (Mobile Office) : 896
# Consultant Aide : 881
# SamCard Pro-card reader&business card scanner&ocr : 875
# ALON Dictaphone - Voice Recorder : 379
# CamCard HD -business card scanner & reader : 319
# VPN Pro | Lifetime Proxy & Best VPN by Betternet : 207
# Time tracker and Invoice - TimeTrack : 169
# Awesome Voice Recorder Pro - Mp3 Audio Recording : 162
# PDF Pro 2 - The ultimate PDF app : 149
# FineScanner Pro - PDF Document Scanner App + OCR : 100
# PDF Export - Photos to PDF and Converter : 41
# RecordOrders : 41
# Call Recorder for iPhone - Record Phone Calls : 39
# Timenote : 11
# Mileage Log | Fahrtenbuch : 8
# Messenger for WhatsApp - Pro App : 6
# Xyngular Back Office : 0

# %% [markdown]
# Business app ratings come in second, which are largely due to the scanner and remote desktop app

# %% [markdown]
# ### App Profile Recommendation
# The above analysis suggests developing a game which is easy to pick up and play withouth the need to learn the mechanics

# %% [markdown]
# # Most Popular Apps by Genre on Google Play
#
# Unlike Apple play store, google play store's most popular apps are

# %%
category_ft = freq_table(free_eng_google_apps, 1)

for cat in category_ft:
    total = 0 # store sum of each category
    len_category = 0 # store number of apps specific to this category
    
    for row in free_eng_google_apps:
        category_app = row[1]
        installs = row[5].replace(',','').replace('+','') # remove non-numeric chars
        installs = float(installs) # convert to float
        
        if cat == category_app:
            total += installs
            len_category += 1
        
    avg_installs = total / len_category
    print(cat,':',avg_installs)
# Out:
# ART_AND_DESIGN : 1986335.0877192982
# AUTO_AND_VEHICLES : 647317.8170731707
# BEAUTY : 513151.88679245283
# BOOKS_AND_REFERENCE : 8767811.894736841
# BUSINESS : 1712290.1474201474
# COMICS : 817657.2727272727
# COMMUNICATION : 38456119.167247385
# DATING : 854028.8303030303
# EDUCATION : 1833495.145631068
# ENTERTAINMENT : 11640705.88235294
# EVENTS : 253542.22222222222
# FINANCE : 1387692.475609756
# FOOD_AND_DRINK : 1924897.7363636363
# HEALTH_AND_FITNESS : 4188821.9853479853
# HOUSE_AND_HOME : 1331540.5616438356
# LIBRARIES_AND_DEMO : 638503.734939759
# LIFESTYLE : 1437816.2687861272
# GAME : 15588015.603248259
# FAMILY : 3697848.1731343283
# MEDICAL : 120550.61980830671
# SOCIAL : 23253652.127118643
# SHOPPING : 7036877.311557789
# PHOTOGRAPHY : 17840110.40229885
# SPORTS : 3638640.1428571427
# TRAVEL_AND_LOCAL : 13984077.710144928
# TOOLS : 10801391.298666667
# PERSONALIZATION : 5201482.6122448975
# PRODUCTIVITY : 16787331.344927534
# PARENTING : 542603.6206896552
# WEATHER : 5074486.197183099
# VIDEO_PLAYERS : 24727872.452830188
# NEWS_AND_MAGAZINES : 9549178.467741935
# MAPS_AND_NAVIGATION : 4056941.7741935486

# %% [markdown]
# Communication apps generally has the highest number of installs.

# %%
for app in free_eng_google_apps:
    if app[1] == 'COMMUNICATION' and (app[5] == '1,000,000,000+'
                                      or app[5] == '500,000,000+'
                                      or app[5] == '100,000,000+'):
        print(app[0], ':', app[5])
# Out:
# WhatsApp Messenger : 1,000,000,000+
# imo beta free calls and text : 100,000,000+
# Android Messages : 100,000,000+
# Google Duo - High Quality Video Calls : 500,000,000+
# Messenger – Text and Video Chat for Free : 1,000,000,000+
# imo free video calls and chat : 500,000,000+
# Skype - free IM & video calls : 1,000,000,000+
# Who : 100,000,000+
# GO SMS Pro - Messenger, Free Themes, Emoji : 100,000,000+
# LINE: Free Calls & Messages : 500,000,000+
# Google Chrome: Fast & Secure : 1,000,000,000+
# Firefox Browser fast & private : 100,000,000+
# UC Browser - Fast Download Private & Secure : 500,000,000+
# Gmail : 1,000,000,000+
# Hangouts : 1,000,000,000+
# Messenger Lite: Free Calls & Messages : 100,000,000+
# Kik : 100,000,000+
# KakaoTalk: Free Calls & Text : 100,000,000+
# Opera Mini - fast web browser : 100,000,000+
# Opera Browser: Fast and Secure : 100,000,000+
# Telegram : 100,000,000+
# Truecaller: Caller ID, SMS spam blocking & Dialer : 100,000,000+
# UC Browser Mini -Tiny Fast Private & Secure : 100,000,000+
# Viber Messenger : 500,000,000+
# WeChat : 100,000,000+
# Yahoo Mail – Stay Organized : 100,000,000+
# BBM - Free Calls & Messages : 100,000,000+

# %% [markdown]
# # Conclusion
#
# The games genre clearly dominates in the apple store. The most popular games have simple mechanics or are simpler to pick up and play than their desktop counterpart.
#
# The Google play store is more evened out, but has a higher demand for social and communication apps. Let's consider this in our conclusion.
#
# Based on the mixed trends between both stores I suggest we develop a multiplayer game which is simple to pick up and play, with features for communicating with other players as well as social connectors such as sharing high scores on social media platforms. This approach takes into account the demand for gaming entertainment seen on the Apple store as well as the need to connecting with others as seen on the Google Play store.
